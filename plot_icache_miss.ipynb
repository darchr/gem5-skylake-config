# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import os

# %%
result_dir = os.getcwd() + '/results/microbenchmark-experiments/'
plot = os.getcwd() + '/images/'

# %%
gem5Configs = ['UnCalib','Calib','Max']
benchmarks = ['CCa','CCe','CCm','CCh_st','CRm','CRf','CRd','CS1','CS3','EI','EF','ED1','EM1','EM5','MI','MC','MCS','MI','MD','MIM','MIM2']
exe_benchmarks = ['ED1','EI','EF','EM1','EM5']
mem_benchmarks = ['MI','MC','MCS','MI','MD','MIM','MIM2']
ctrl_benchmarks = ['CCa','CCe','CCm','CCh_st','CRm','CRf','CRd','CS1','CS3']

# %%
# function to extract stats
def gem5GetStat(filename, stat):
    filename = os.path.join(result_dir, '', filename, 'stats.txt').replace('\\','/')
    with open(filename) as f:
        r = f.read()
        if len(r) < 10: return 0.0
        start = r.find(stat) + len(stat) + 1
        end = r.find('#', start)
        return float(r[start:end])

# %%
rows = []
for config in gem5Configs:
    cdir = result_dir + config + '/'
    for bm in benchmarks:
        rows.append([config, bm,
                     gem5GetStat(cdir + bm, 'system.cpu.icache.overall_misses::total')])

gem5_df = pd.DataFrame(rows, columns=['config', 'benchmark', 'system.cpu.icache.overall_misses::total'])

# %%
def CreateArray(config,benchmarks,stat):
    arr = []
    for bm in benchmarks:
        a = gem5_df[(gem5_df['benchmark']==bm) & (gem5_df['config']==config)]
        arr.append(a[stat].iloc[0])
    return arr

# %%
plot_title = 'ICache Misses'

ylabel = 'icache misses'
plt.figure()
plt.figure(figsize=(12,6))
N = np.arange(len(benchmarks))
barwidth = 0.2
displacement1 = N + barwidth
displacement2 = displacement1 + barwidth

UnCalib_cache_miss = CreateArray('UnCalib',benchmarks,'system.cpu.icache.overall_misses::total')
Calib_cache_miss = CreateArray('Calib',benchmarks,'system.cpu.icache.overall_misses::total')
Max_cache_miss = CreateArray('Max',benchmarks,'system.cpu.icache.overall_misses::total')

plt.bar(N, UnCalib_cache_miss, barwidth, label='UnCalibrated CPU', color='lightblue')
plt.bar(displacement1, Calib_cache_miss, barwidth, label= 'Calibrated CPU', color='cornflowerblue')
plt.bar(displacement2, Max_cache_miss, barwidth, label='Max CPU', color='red')

plt.title(plot_title)
plt.legend(bbox_to_anchor=(0.25, 1))
plt.xticks(N+0.2, benchmarks, rotation=40, ha='right')
plt.ylabel(ylabel)
plt.tight_layout()
# plt.savefig(plot + 'microbenchmark_IPC' + '.png', format='png', dpi=600)

# %%
plot_title = 'ICache misses'

benchmarks = mem_benchmarks
ylabel = 'Icache misses'
plt.figure()
plt.figure(figsize=(8,6))
N = np.arange(len(benchmarks))
barwidth = 0.2
displacement1 = N + barwidth
displacement2 = displacement1 + barwidth

UnCalib_cache_miss = CreateArray('UnCalib',benchmarks,'system.cpu.icache.overall_misses::total')
Calib_cache_miss = CreateArray('Calib',benchmarks,'system.cpu.icache.overall_misses::total')
Max_cache_miss = CreateArray('Max',benchmarks,'system.cpu.icache.overall_misses::total')

plt.bar(N, UnCalib_cache_miss, barwidth, label='UnCalibrated CPU', color='lightblue')
plt.bar(displacement1, Calib_cache_miss, barwidth, label= 'Calibrated CPU', color='cornflowerblue')
plt.bar(displacement2, Max_cache_miss, barwidth, label='Max CPU', color='red')

plt.title(plot_title)
plt.legend(bbox_to_anchor=(0.15, 1))
plt.xticks(N+0.2, benchmarks, rotation=40, ha='right')
plt.ylabel(ylabel)
plt.tight_layout()
# plt.savefig(plot + 'exe_IPC' + '.png', format='png', dpi=600)

# %%
plot_title = 'ICache misses'

benchmarks = ctrl_benchmarks
ylabel = 'Icache misses'
plt.figure()
plt.figure(figsize=(8,6))
N = np.arange(len(benchmarks))
barwidth = 0.2
displacement1 = N + barwidth
displacement2 = displacement1 + barwidth

UnCalib_cache_miss = CreateArray('UnCalib',benchmarks,'system.cpu.icache.overall_misses::total')
Calib_cache_miss = CreateArray('Calib',benchmarks,'system.cpu.icache.overall_misses::total')
Max_cache_miss = CreateArray('Max',benchmarks,'system.cpu.icache.overall_misses::total')

plt.bar(N, UnCalib_cache_miss, barwidth, label='UnCalibrated CPU', color='lightblue')
plt.bar(displacement1, Calib_cache_miss, barwidth, label= 'Calibrated CPU', color='cornflowerblue')
plt.bar(displacement2, Max_cache_miss, barwidth, label='Max CPU', color='red')

plt.title(plot_title)
plt.legend(bbox_to_anchor=(0.10, 1))
plt.xticks(N+0.2, benchmarks, rotation=40, ha='right')
plt.ylabel(ylabel)
plt.tight_layout()
# plt.savefig(plot + 'exe_IPC' + '.png', format='png', dpi=600)

# %%
plot_title = 'ICache misses'

benchmarks = exe_benchmarks
ylabel = 'Icache misses'
plt.figure()
plt.figure(figsize=(8,6))
N = np.arange(len(benchmarks))
barwidth = 0.2
displacement1 = N + barwidth
displacement2 = displacement1 + barwidth

UnCalib_cache_miss = CreateArray('UnCalib',benchmarks,'system.cpu.icache.overall_misses::total')
Calib_cache_miss = CreateArray('Calib',benchmarks,'system.cpu.icache.overall_misses::total')
Max_cache_miss = CreateArray('Max',benchmarks,'system.cpu.icache.overall_misses::total')

plt.bar(N, UnCalib_cache_miss, barwidth, label='UnCalibrated CPU', color='lightblue')
plt.bar(displacement1, Calib_cache_miss, barwidth, label= 'Calibrated CPU', color='cornflowerblue')
plt.bar(displacement2, Max_cache_miss, barwidth, label='Max CPU', color='red')

plt.title(plot_title)
plt.legend(bbox_to_anchor=(0.10, 1))
plt.xticks(N+0.2, benchmarks, rotation=40, ha='right')
plt.ylabel(ylabel)
plt.tight_layout()
# plt.savefig(plot + 'exe_IPC' + '.png', format='png', dpi=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a61467db5284> in <module>
#       3 benchmarks = exe_benchmarks
#       4 ylabel = 'Icache misses'
# ----> 5 plt.figure()
#       6 plt.figure(figsize=(8,6))
#       7 N = np.arange(len(benchmarks))
#
# NameError: name 'plt' is not defined
